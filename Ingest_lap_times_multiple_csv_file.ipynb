# %%
# %run "/Workspace/Users/sundaramloganathan@outlook.com/includes/storage_acc_config"

# %%
# %run "../includes/folder_path"

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DoubleType, DateType, TimestampType

lap_schema = StructType(fields=[
    StructField("raceId", IntegerType(), True),
    StructField("driverId", IntegerType(), True),
    StructField("lap", IntegerType(), True),
    StructField("position", IntegerType(), True),
    StructField("time", StringType(), True),
    StructField("milliseconds", IntegerType(), True)])

# %%
lap_df = spark.read \
         .schema(lap_schema) \
         .csv(f"{bronze_folder_path}/lap_times")

# %%
from pyspark.sql.functions import current_timestamp

lap_upd_df = lap_df.withColumnRenamed("raceId", "race_id") \
                   .withColumnRenamed("driverId", "driver_id") \
                   .withColumn("ingestion_date", current_timestamp())

# %%
lap_upd_df.write.mode("overwrite") \
          .parquet(f"{silver_folder_path}/lap_times")
