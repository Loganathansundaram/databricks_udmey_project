# %%
v_result = dbutils.notebook.run("ingest_circuits_file_final", 0, {"p_data_source": "Loganathan"})

# %%
v_result

# %%
v_result = dbutils.notebook.run("ingest_constructors_json_file", 0, {"p_data_source": "Loganathan"})

# %%
v_result

# %%
v_result = dbutils.notebook.run("ingest_divers_json_file", 0, {"p_data_source": "Loganathan"})

# %%
v_result

# %%
v_result = dbutils.notebook.run("Ingest_lap_times_multiple_csv_file", 0, {"p_data_source": "Loganathan"})

# %%
v_result

# %%
v_result = dbutils.notebook.run("Ingest_pit_stops_multiline_json", 0, {"p_data_source": "Loganathan"})

# %%
v_result

# %%
v_result = dbutils.notebook.run("Ingest_pit_stops_multiline_json", 0, {"p_data_source": "Loganathan"})

# %%
v_result

# %%
v_result = dbutils.notebook.run("ingest_races_file", 0, {"p_data_source": "Loganathan"})

# %%
v_result

# %%
v_result = dbutils.notebook.run("Ingest_results_json_file", 0, {"p_data_source": "Loganathan"})

# %%
v_result
